# %% [markdown]
# # Survival Analysis Lab
#
# Complete the following exercises to solidify your knowledge of survival analysis.

# %%
# !pip install plotly==4.14.3

# %%
# !pip install cufflinks
# Out:
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68724 sha256=6fe2d2ddd0b0cc80c8c16ec58269747cfcb485e3c8576f26b39897d0d41c6a74
#   Stored in directory: c:\users\c725676\appdata\local\pip\cache\wheels\6b\76\62\6da97734911ffcbdd559fd1a3f28526321f0ae699182a23866
# Successfully built cufflinks
# ...

# %%
import pandas as pd
import plotly as py
import cufflinks as cf
from lifelines import KaplanMeierFitter

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('../data/attrition.csv')

# %%
data.head(5)
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## 1. Generate and plot a survival function that shows how employee retention rates vary by gender and employee age.
#
# *Tip: If your lines have gaps in them, you can fill them in by using the `fillna(method=ffill)` and the `fillna(method=bfill)` methods and then taking the average. We have provided you with a revised survival function below that you can use for the exercises in this lab*

# %%
def survival(data, group_field, time_field, event_field):
    kmf = KaplanMeierFitter()
    results = []

    for i in data[group_field].unique():
        group = data[data[group_field]==i]
        T = group[time_field]
        E = group[event_field]
        kmf.fit(T, E, label=str(i))
        results.append(kmf.survival_function_)

    survival = pd.concat(results, axis=1)
    front_fill = survival.fillna(method='ffill')
    back_fill = survival.fillna(method='bfill')
    smoothed = (front_fill + back_fill) / 2
    return smoothed

# %%
employee_age = survival(data, 'Gender', 'Age', 'Attrition')

# %%
employee_age
# Out:
#             Female      Male
# timeline
# 0.0       1.000000  1.000000
# 18.0      0.998299  0.996599
# 19.0      0.994880  0.992058
# 20.0      0.988019  0.989786
# 21.0      0.979413  0.988645
# 22.0      0.975964  0.985201
# 23.0      0.975964  0.980564
# 24.0      0.969018  0.977050
# 25.0      0.969018  0.969918
# 26.0      0.963684  0.959034
# 27.0      0.960054  0.957799
# 28.0      0.954396  0.943770
# 29.0      0.935192  0.933211
# 30.0      0.925201  0.927689
# 31.0      0.910549  0.911794
# 32.0      0.903950  0.899657
# 33.0      0.890079  0.890069
# 34.0      0.880378  0.881656
# 35.0      0.872470  0.868931
# 36.0      0.869628  0.858920
# 37.0      0.866500  0.848020
# 38.0      0.866500  0.843335
# 39.0      0.859062  0.833144
# 40.0      0.855104  0.822217
# 41.0      0.837381  0.816172
# 42.0      0.837381  0.809563
# 43.0      0.832212  0.805832
# 44.0      0.826589  0.785585
# 45.0      0.814610  0.785585
# 46.0      0.801145  0.775249
# ...

# %%
employee_age.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 2. Compare the plot above with one that plots employee retention rates by gender over the number of years the employee has been working for the company.

# %%
employee_year = survival(data, 'Gender', 'YearsAtCompany', 'Attrition')
employee_year
# Out:
#             Female      Male
# timeline
# 0.0       0.993197  0.986395
# 1.0       0.956797  0.942452
# 2.0       0.938000  0.920975
# 3.0       0.923879  0.902917
# 4.0       0.912585  0.881528
# 5.0       0.890624  0.861027
# 6.0       0.881315  0.848334
# 7.0       0.864235  0.834195
# 8.0       0.848663  0.820565
# 9.0       0.830314  0.808084
# 10.0      0.796878  0.763398
# 11.0      0.789826  0.757658
# 12.0      0.789826  0.757658
# 13.0      0.781241  0.750643
# 14.0      0.781241  0.734671
# 15.0      0.770391  0.734671
# 16.0      0.770391  0.725005
# 17.0      0.756634  0.725005
# 18.0      0.756634  0.714020
# 19.0      0.756634  0.702119
# 20.0      0.756634  0.689354
# 21.0      0.756634  0.672940
# 22.0      0.714598  0.672940
# 23.0      0.682117  0.647058
# 24.0      0.649635  0.647058
# 25.0      0.649635  0.647058
# 26.0      0.649635  0.647058
# 27.0      0.649635  0.647058
# 29.0      0.649635  0.647058
# 30.0      0.541362  0.647058
# ...

# %%
employee_year.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 3. Let's look at retention rate by gender from a third perspective - the number of years since the employee's last promotion. Generate and plot a survival curve showing this.

# %%
employee_lastp = survival(data, 'Gender', 'YearsSinceLastPromotion', 'Attrition')
employee_lastp
# Out:
#             Female      Male
# timeline
# 0.0       0.931973  0.920635
# 1.0       0.882785  0.868425
# 2.0       0.854697  0.812757
# 3.0       0.828797  0.797127
# 4.0       0.817041  0.783841
# 5.0       0.809874  0.778473
# 6.0       0.792074  0.753361
# 7.0       0.720068  0.689396
# 8.0       0.720068  0.689396
# 9.0       0.720068  0.637366
# 10.0      0.695238  0.637366
# 11.0      0.695238  0.605498
# 12.0      0.695238  0.605498
# 13.0      0.695238  0.544948
# 14.0      0.695238  0.503029
# 15.0      0.397279  0.503029

# %%
employee_lastp.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 4. Let's switch to looking at retention rates from another demographic perspective: marital status. Generate and plot survival curves for the different marital statuses by number of years at the company.

# %%
marit_year = survival(data, 'MaritalStatus', 'YearsAtCompany', 'Attrition')
marit_year
# Out:
#             Single   Married  Divorced
# timeline
# 0.0       0.970213  0.997028  1.000000
# 1.0       0.904361  0.965353  0.975232
# 2.0       0.873585  0.950602  0.958063
# 3.0       0.858123  0.938070  0.932069
# 4.0       0.826763  0.932018  0.912153
# 5.0       0.786051  0.916410  0.907767
# 6.0       0.762818  0.910856  0.902129
# 7.0       0.753999  0.895776  0.876895
# 8.0       0.723432  0.885786  0.876895
# 9.0       0.699713  0.870177  0.876895
# 10.0      0.650733  0.823891  0.865652
# 11.0      0.641302  0.817026  0.865652
# 12.0      0.641302  0.817026  0.865652
# 13.0      0.629426  0.808603  0.865652
# 14.0      0.629426  0.789350  0.865652
# 15.0      0.614788  0.789350  0.865652
# 16.0      0.614788  0.776821  0.865652
# 17.0      0.597223  0.776821  0.865652
# 18.0      0.597223  0.776821  0.836797
# 19.0      0.576629  0.776821  0.836797
# 20.0      0.576629  0.759933  0.836797
# 21.0      0.540590  0.759933  0.836797
# 22.0      0.540590  0.731788  0.836797
# ...

# %%
marit_year.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 5. Let's also look at the marital status curves by employee age. Generate and plot the survival curves showing retention rates by marital status and age.

# %%
marit_age = survival(data, 'MaritalStatus', 'Age', 'Attrition')
marit_age
# Out:
#             Single   Married  Divorced
# timeline
# 0.0       1.000000  1.000000  1.000000
# 18.0      0.991489  0.997771  1.000000
# 19.0      0.978613  0.997771  1.000000
# 20.0      0.965651  0.997771  1.000000
# 21.0      0.952543  0.997771  1.000000
# 22.0      0.948102  0.995542  1.000000
# 23.0      0.945871  0.992539  0.996923
# 24.0      0.939115  0.986496  0.996923
# 25.0      0.934578  0.980360  0.996923
# 26.0      0.920801  0.975676  0.987337
# 27.0      0.918458  0.974079  0.984089
# 28.0      0.899019  0.967464  0.977372
# 29.0      0.876544  0.957280  0.966975
# 30.0      0.863615  0.951992  0.963284
# 31.0      0.842092  0.935451  0.959352
# 32.0      0.819785  0.929665  0.959352
# 33.0      0.796109  0.923549  0.955011
# 34.0      0.783670  0.917135  0.945828
# 35.0      0.773448  0.910257  0.925811
# 36.0      0.765902  0.905200  0.915290
# 37.0      0.757532  0.899629  0.904128
# 38.0      0.757532  0.893711  0.904128
# 39.0      0.747694  0.883961  0.897431
# ...

# %%
marit_age.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 6. Now that we have looked at the retention rates by gender and marital status individually, let's look at them together.
#
# Create a new field in the data set that concatenates marital status and gender, and then generate and plot a survival curve that shows the retention by this new field over the age of the employee.

# %%
data['gender/marital'] = data['Gender'] + ' ' + data['MaritalStatus']

# %%
marit_gen = survival(data, 'gender/marital', 'Age', 'Attrition')
marit_gen
# Out:
#           Female Single  Male Married  Male Single  Female Married  \
# timeline
# 0.0            1.000000      1.000000     1.000000        1.000000
# 18.0           0.994975      0.998753     0.988930        0.996324
# 19.0           0.984770      0.998753     0.974114        0.996324
# 20.0           0.964147      0.998753     0.966678        0.996324
# 21.0           0.938089      0.998753     0.962917        0.996324
# 22.0           0.938089      0.997506     0.955214        0.992647
# 23.0           0.938089      0.992456     0.951346        0.988943
# 24.0           0.927489      0.987353     0.947431        0.985239
# 25.0           0.927489      0.976960     0.939536        0.985239
# 26.0           0.927489      0.974298     0.915650        0.977690
# 27.0           0.922033      0.974298     0.915650        0.973825
# 28.0           0.910579      0.965850     0.890332        0.969818
# 29.0           0.887380      0.960032     0.868403        0.953518
# ...

# %%
marit_gen.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 6. Let's find out how job satisfaction affects retention rates. Generate and plot survival curves for each level of job satisfaction by number of years at the company.

# %%
job_y = survival(data, 'JobSatisfaction', 'YearsAtCompany', 'Attrition')
job_y
# Out:
#                  4         2         3         1
# timeline
# 0.0       0.995643  0.992857  0.986425  0.979239
# 1.0       0.964529  0.942312  0.947061  0.929747
# 2.0       0.952320  0.926340  0.916996  0.907070
# 3.0       0.946909  0.909106  0.903268  0.871107
# 4.0       0.929043  0.899587  0.884896  0.848885
# 5.0       0.922568  0.857253  0.874841  0.808701
# 6.0       0.918522  0.857253  0.848726  0.796540
# 7.0       0.904318  0.849988  0.825911  0.783264
# 8.0       0.893290  0.817913  0.815651  0.775189
# 9.0       0.875424  0.808291  0.802806  0.757162
# 10.0      0.838013  0.773148  0.773876  0.691321
# 11.0      0.826839  0.773148  0.773876  0.676612
# 12.0      0.826839  0.773148  0.773876  0.676612
# 13.0      0.826839  0.773148  0.761785  0.660503
# 14.0      0.810302  0.773148  0.748873  0.660503
# 15.0      0.810302  0.747376  0.748873  0.660503
# 16.0      0.787151  0.747376  0.748873  0.660503
# 17.0      0.787151  0.747376  0.748873  0.635099
# ...

# %%
job_y.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 7. Let's investigate whether the department the employee works in has an impact on how long they stay with the company. Generate and plot survival curves showing retention by department and years the employee has worked at the company.

# %%
job_d = survival(data, 'Department', 'YearsAtCompany', 'Attrition')
job_d
# Out:
#              Sales  Research & Development  Human Resources
# timeline
# 0.0       0.984305                0.990635         1.000000
# 1.0       0.945300                0.950331         0.936508
# 2.0       0.915836                0.935116         0.904215
# 3.0       0.889135                0.924938         0.868046
# 4.0       0.868928                0.909285         0.847378
# 5.0       0.847282                0.888583         0.825079
# 6.0       0.828537                0.880524         0.825079
# 7.0       0.820453                0.862415         0.790701
# 8.0       0.797145                0.852025         0.790701
# 9.0       0.775888                0.839853         0.790701
# 10.0      0.750239                0.788731         0.790701
# 11.0      0.731940                0.788731         0.790701
# 12.0      0.731940                0.788731         0.734222
# 13.0      0.720850                0.782521         0.734222
# ...

# %%
job_d.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 8. From the previous example, it looks like the sales department has the highest attrition. Let's drill down on this and look at what the survival curves for specific job roles within that department look like.
#
# Filter the data set for just the sales department and then generate and plot survival curves by job role and the number of years at the company.

# %%
data_s = data[data['Department'] == 'Sales']

# %%
job_rd = survival(data_s, 'JobRole', 'YearsAtCompany', 'Attrition')
job_rd
# Out:
#           Sales Executive  Manager  Sales Representative
# timeline
# 0.0              0.990798    1.000              0.951807
# 1.0              0.978295    1.000              0.788998
# 2.0              0.952294    1.000              0.729451
# 3.0              0.942018    1.000              0.583561
# 4.0              0.923761    1.000              0.527984
# 5.0              0.904273    1.000              0.457586
# 6.0              0.880094    1.000              0.457586
# 7.0              0.869554    1.000              0.457586
# 8.0              0.839150    1.000              0.457586
# 9.0              0.817995    1.000              0.381322
# 10.0             0.783553    1.000              0.381322
# 11.0             0.756534    1.000              0.381322
# 12.0             0.756534    1.000              0.381322
# 13.0             0.739722    1.000              0.381322
# 14.0             0.700790    1.000                   NaN
# ...

# %%
job_rd.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 9. Let examine how compensation affects attrition.
#
# - Use the `pd.qcut` method to bin the HourlyRate field into 5 different pay grade categories (Very Low, Low, Moderate, High, and Very High).
# - Generate and plot survival curves showing employee retention by pay grade and age.

# %%
data['HourlyRate']
# Out:
# 0       94
# 1       61
# 2       92
# 3       56
# 4       40
#         ..
# 1465    41
# 1466    42
# 1467    87
# 1468    63
# 1469    82
# Name: HourlyRate, Length: 1470, dtype: int64

# %%
data['hourly_paygrade'] = pd.cut(data['HourlyRate'], 5, labels=['Very Low', 'Low', 'Moderate', 'High', 'Very High'])

# %%
data[['HourlyRate', 'hourly_paygrade']].head(10)
# Out:
#    HourlyRate hourly_paygrade
# 0          94       Very High
# 1          61        Moderate
# 2          92       Very High
# 3          56             Low
# 4          40        Very Low
# 5          79            High
# 6          81            High
# 7          67        Moderate
# 8          44        Very Low
# 9          94       Very High

# %%
job_pay = survival(data, 'hourly_paygrade', 'Age', 'Attrition')
job_pay
# Out:
#           Very High  Moderate       Low  Very Low      High
# timeline
# 0.0        1.000000  1.000000  1.000000  1.000000  1.000000
# 18.0       1.000000  0.992780  0.996678  1.000000  0.996774
# 19.0       0.993311  0.990968  0.986711  0.996441  0.996774
# 20.0       0.989967  0.989156  0.980021  0.992883  0.993527
# 21.0       0.983255  0.985533  0.976665  0.985714  0.990270
# 22.0       0.979864  0.985533  0.973286  0.982116  0.987012
# 23.0       0.973012  0.981842  0.973286  0.978492  0.987012
# 24.0       0.966136  0.970727  0.966432  0.978492  0.987012
# 25.0       0.962648  0.966979  0.962943  0.971079  0.983678
# 26.0       0.959109  0.959365  0.945306  0.963552  0.976894
# 27.0       0.959109  0.959365  0.938063  0.963552  0.973466
# 28.0       0.955377  0.951269  0.919301  0.955588  0.959255
# 29.0       0.947764  0.947097  0.896223  0.939183  0.940879
# 30.0       0.939732  0.934063  0.888291  0.934875  0.937054
# ...

# %%
job_pay.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 10. Finally, let's take a look at how the demands of the job impact employee attrition.
#
# - Create a new field whose values are 'Overtime' or 'Regular Hours' depending on whether there is a Yes or a No in the OverTime field.
# - Create a new field that concatenates that field with the BusinessTravel field.
# - Generate and plot survival curves showing employee retention based on these conditions and employee age.

# %%
data['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
import numpy as np

# %%
data_copy = data.copy

# %%
data['working_time'] = np.where(data['OverTime'] == 'Yes', 'OverTime', 'Regular Hours')

# %%
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# ...

# %%
data['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
data['buss_worktime'] = data['working_time'] + ' ' + data['BusinessTravel']

# %%
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
job_ret = survival(data, 'buss_worktime', 'Age', 'Attrition')
job_ret
# Out:
#           OverTime Travel_Rarely  Regular Hours Travel_Frequently  \
# timeline
# 0.0                     1.000000                         1.000000
# 18.0                    0.996610                         0.997382
# 19.0                    0.993220                         0.994764
# 20.0                    0.986417                         0.992147
# 21.0                    0.986417                         0.989529
# 22.0                    0.976142                         0.984293
# 23.0                    0.965831                         0.979058
# 24.0                    0.958957                         0.979058
# 25.0                    0.948533                         0.979058
# 26.0                    0.934429                         0.973737
# 27.0                    0.930848                         0.968266
# 28.0                    0.905094                         0.951078
# 29.0                    0.875540                         0.939550
# ...

# %%
job_ret.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>
